# %%
import pandas as pd

# %%
clean_results_lstm_nsl = {
    'f1': 0.9810269799825936,
    'precision': 0.9764379764379765,
    'recall': 0.9856593214410633,
    'mcc': 0.963306497032815,
    'specificity': 0.9779364049318306,
    'balanced_accuracy': 0.981797863186447
}

clean_results_lstm_unsw = {
    'f1': 0.9315194835139496, 
    'precision': 0.9433374844333748, 
    'recall': 0.9199939274328223, 
    'mcc': 0.8148487010682461, 
    'specificity': 0.9021505376343844, 
    'balanced_accuracy': 0.9110722325336034
}


normal_lstm = [
    # FGSM
    ["UNSW-NB15","FGSM", 0.01, 0.8096, 0.8292, 0.7910, 0.4947, 0.7116, 0.7513],
    ["UNSW-NB15","FGSM", 0.03, 0.4563, 0.6077, 0.3653, -0.0516, 0.5825, 0.4739],
    ["UNSW-NB15","FGSM", 0.05, 0.3298, 0.4729, 0.2532, -0.2495, 0.5003, 0.3767],
    ["UNSW-NB15","FGSM", 0.07, 0.2853, 0.3705, 0.2320, -0.4567, 0.3022, 0.2671],

    # PGD
    ["UNSW-NB15","PGD", 0.01, 0.7876, 0.8066, 0.7694, 0.4359, 0.6734, 0.7214],
    ["UNSW-NB15","PGD", 0.03, 0.0897, 0.1822, 0.0595, -0.4887, 0.5269, 0.2932],
    ["UNSW-NB15","PGD", 0.05, 0.0710, 0.1393, 0.0477, -0.5505, 0.4785, 0.2631],
    ["UNSW-NB15","PGD", 0.07, 0.0483, 0.0871, 0.0334, -0.6551, 0.3798, 0.2066],

    # MI-FGSM
    ["UNSW-NB15","MI-FGSM", 0.01, 0.7921, 0.8115, 0.7736, 0.4482, 0.6817, 0.7277],
    ["UNSW-NB15","MI-FGSM", 0.03, 0.0973, 0.1952, 0.0648, -0.4798, 0.5266, 0.2957],
    ["UNSW-NB15","MI-FGSM", 0.05, 0.0698, 0.1373, 0.0468, -0.5512, 0.4796, 0.2632],
    ["UNSW-NB15","MI-FGSM", 0.07, 0.0491, 0.0800, 0.0354, -0.7303, 0.2801, 0.1577],
    
    # FGSM
    ["NSL-KDD", "FGSM", 0.01, 0.9325, 0.9186, 0.9468, 0.8684, 0.9221, 0.9345],
    ["NSL-KDD", "FGSM", 0.03, 0.6596, 0.5445, 0.8363, 0.2132, 0.3511, 0.5937],
    ["NSL-KDD", "FGSM", 0.05, 0.6205, 0.5133, 0.7842, 0.1069, 0.3102, 0.5472],
    ["NSL-KDD", "FGSM", 0.07, 0.6540, 0.5588, 0.7884, 0.2256, 0.4225, 0.6054],

    # PGD
    ["NSL-KDD", "PGD", 0.01, 0.9116, 0.8946, 0.9293, 0.8272, 0.8984, 0.9139],
    ["NSL-KDD", "PGD", 0.03, 0.5864, 0.4832, 0.7457, 0.0068, 0.2602, 0.5030],
    ["NSL-KDD", "PGD", 0.05, 0.4708, 0.3785, 0.6226, -0.4008, 0.0516, 0.3371],
    ["NSL-KDD", "PGD", 0.07, 0.3405, 0.2858, 0.4211, -0.6103, 0.0240, 0.2226],

    # MI-FGSM
    ["NSL-KDD", "MI-FGSM", 0.01, 0.9160, 0.8968, 0.9360, 0.8355, 0.9001, 0.9180],
    ["NSL-KDD", "MI-FGSM", 0.03, 0.5637, 0.4466, 0.7643, -0.1500, 0.1213, 0.4428],
    ["NSL-KDD", "MI-FGSM", 0.05, 0.4686, 0.3746, 0.6254, -0.4314, 0.0315, 0.3284],
    ["NSL-KDD", "MI-FGSM", 0.07, 0.3865, 0.3226, 0.4820, -0.5081, 0.0610, 0.2715],
]

adv_lstm = [

    # FGSM
    ["UNSW-NB15","FGSM", 0.01, 0.9217, 0.8570, 0.9970, 0.7724, 0.7054, 0.8512],
    ["UNSW-NB15","FGSM", 0.03, 0.9204, 0.8565, 0.9947, 0.7681, 0.7048, 0.8498],
    ["UNSW-NB15","FGSM", 0.05, 0.9169, 0.8528, 0.9913, 0.7565, 0.6970, 0.8442],
    ["UNSW-NB15","FGSM", 0.07, 0.8594, 0.7854, 0.9487, 0.5606, 0.5411, 0.7449],

    # PGD
    ["UNSW-NB15","PGD", 0.01, 0.9217, 0.8570, 0.9970, 0.7724, 0.7054, 0.8512],
    ["UNSW-NB15","PGD", 0.03, 0.9204, 0.8565, 0.9947, 0.7681, 0.7048, 0.8498],
    ["UNSW-NB15","PGD", 0.05, 0.9099, 0.8459, 0.9844, 0.7336, 0.6825, 0.8334],
    ["UNSW-NB15","PGD", 0.07, 0.8320, 0.7526, 0.9302, 0.4583, 0.4586, 0.6944],

    # MI-FGSM
    ["UNSW-NB15","MI-FGSM", 0.01, 0.9217, 0.8570, 0.9970, 0.7724, 0.7054, 0.8512],
    ["UNSW-NB15","MI-FGSM", 0.03, 0.9204, 0.8565, 0.9947, 0.7681, 0.7048, 0.8498],
    ["UNSW-NB15","MI-FGSM", 0.05, 0.9123, 0.8483, 0.9868, 0.7416, 0.6876, 0.8372],
    ["UNSW-NB15","MI-FGSM", 0.07, 0.8363, 0.7587, 0.9315, 0.4756, 0.4755, 0.7035],

    # FGSM
    ["NSL-KDD", "FGSM", 0.01, 0.9720, 0.9863, 0.9580, 0.9470, 0.9877, 0.9728],
    ["NSL-KDD", "FGSM", 0.03, 0.9615, 0.9811, 0.9426, 0.9277, 0.9831, 0.9629],
    ["NSL-KDD", "FGSM", 0.05, 0.9464, 0.9678, 0.9258, 0.8995, 0.9714, 0.9486],
    ["NSL-KDD", "FGSM", 0.07, 0.9247, 0.9352, 0.9143, 0.8565, 0.9413, 0.9278],

    # PGD
    ["NSL-KDD", "PGD", 0.01, 0.9720, 0.9863, 0.9580, 0.9470, 0.9877, 0.9728],
    ["NSL-KDD", "PGD", 0.03, 0.9593, 0.9789, 0.9405, 0.9237, 0.9812, 0.9609],
    ["NSL-KDD", "PGD", 0.05, 0.9320, 0.9489, 0.9157, 0.8716, 0.9543, 0.9350],
    ["NSL-KDD", "PGD", 0.07, 0.8905, 0.8979, 0.8832, 0.7906, 0.9069, 0.8950],

    # MI-FGSM
    ["NSL-KDD", "MI-FGSM", 0.01, 0.9720, 0.9863, 0.9580, 0.9470, 0.9877, 0.9728],
    ["NSL-KDD", "MI-FGSM", 0.03, 0.9595, 0.9792, 0.9405, 0.9240, 0.9815, 0.9610],
    ["NSL-KDD", "MI-FGSM", 0.05, 0.9340, 0.9511, 0.9175, 0.8753, 0.9562, 0.9368],
    ["NSL-KDD", "MI-FGSM", 0.07, 0.9006, 0.9059, 0.8954, 0.8095, 0.9137, 0.9046]
]


gan_lstm = [

    # FGSM
    ["UNSW-NB15","FGSM", 0.01, 0.9200, 0.8540, 0.9971, 0.7672, 0.6981, 0.8476],
    ["UNSW-NB15","FGSM", 0.03, 0.9195, 0.8535, 0.9967, 0.7657, 0.6970, 0.8469],
    ["UNSW-NB15","FGSM", 0.05, 0.9167, 0.8505, 0.9941, 0.7564, 0.6906, 0.8423],
    ["UNSW-NB15","FGSM", 0.07, 0.9116, 0.8478, 0.9857, 0.7390, 0.6866, 0.8361],

    # PGD
    ["UNSW-NB15","PGD", 0.01, 0.9200, 0.8540, 0.9971, 0.7672, 0.6981, 0.8476],
    ["UNSW-NB15","PGD", 0.03, 0.9194, 0.8534, 0.9965, 0.7652, 0.6968, 0.8466],
    ["UNSW-NB15","PGD", 0.05, 0.9159, 0.8496, 0.9933, 0.7536, 0.6887, 0.8410],
    ["UNSW-NB15","PGD", 0.07, 0.9088, 0.8430, 0.9857, 0.7302, 0.6750, 0.8304],

    # MI-FGSM
    ["UNSW-NB15","MI-FGSM", 0.01, 0.9200, 0.8540, 0.9971, 0.7672, 0.6981, 0.8476],
    ["UNSW-NB15","MI-FGSM", 0.03, 0.9195, 0.8537, 0.9964, 0.7655, 0.6976, 0.8470],
    ["UNSW-NB15","MI-FGSM", 0.05, 0.9165, 0.8500, 0.9944, 0.7559, 0.6892, 0.8418],
    ["UNSW-NB15","MI-FGSM", 0.07, 0.9103, 0.8461, 0.9850, 0.7348, 0.6828, 0.8339],

    
    # FGSM (GAN purified)
    ["NSL-KDD", "FGSM", 0.01, 0.9656, 0.9747, 0.9566, 0.9344, 0.9770, 0.9668],
    ["NSL-KDD", "FGSM", 0.03, 0.9577, 0.9702, 0.9454, 0.9196, 0.9731, 0.9593],
    ["NSL-KDD", "FGSM", 0.05, 0.9521, 0.9665, 0.9381, 0.9092, 0.9698, 0.9540],
    ["NSL-KDD", "FGSM", 0.07, 0.9138, 0.9101, 0.9175, 0.8332, 0.9160, 0.9167],

    # PGD (GAN purified)
    ["NSL-KDD", "PGD", 0.01, 0.9654, 0.9747, 0.9563, 0.9340, 0.9770, 0.9666],
    ["NSL-KDD", "PGD", 0.03, 0.9584, 0.9709, 0.9461, 0.9210, 0.9737, 0.9599],
    ["NSL-KDD", "PGD", 0.05, 0.9535, 0.9686, 0.9388, 0.9120, 0.9718, 0.9553],
    ["NSL-KDD", "PGD", 0.07, 0.9339, 0.9411, 0.9269, 0.8736, 0.9461, 0.9365],

    # MI-FGSM (GAN purified)
    ["NSL-KDD", "MI-FGSM", 0.01, 0.9656, 0.9750, 0.9563, 0.9344, 0.9773, 0.9668],
    ["NSL-KDD", "MI-FGSM", 0.03, 0.9582, 0.9702, 0.9465, 0.9206, 0.9731, 0.9598],
    ["NSL-KDD", "MI-FGSM", 0.05, 0.9533, 0.9672, 0.9398, 0.9116, 0.9705, 0.9552],
    ["NSL-KDD", "MI-FGSM", 0.07, 0.9347, 0.9408, 0.9286, 0.8749, 0.9458, 0.9372],
]


# Create DataFrame
df = pd.DataFrame(gan_lstm, columns=[
    "Dataset", "Attack", "Epsilon", "F1", "Precision", "Recall", "MCC", "Specificity", "Balanced_Acc"
])

# %%
clean_results_cnn_unsw= {
    'f1': 0.9481302774427021, 
    'precision': 0.9417403025310769, 
    'recall': 0.9546075603461364, 
    'mcc': 0.85469167173334, 
    'specificity': 0.8954301075268576, 
    'balanced_accuracy': 0.925018833936497
}

clean_results_cnn_nsl= {
    'f1': 0.988429172510519, 
    'precision': 0.9908611599297013, 
    'recall': 0.9860090940888423, 
    'mcc': 0.9777571211186512, 
    'specificity': 0.9915639195327387, 
    'balanced_accuracy': 0.9887865068107905
}


normal_cnn = [

    # FGSM
    ["UNSW-NB15", "FGSM", 0.01, 0.8528, 0.8419, 0.8640, 0.5829, 0.7126, 0.7883],
    ["UNSW-NB15", "FGSM", 0.03, 0.7007, 0.7606, 0.6496, 0.2773, 0.6379, 0.6438],
    ["UNSW-NB15", "FGSM", 0.05, 0.5175, 0.5928, 0.4592, -0.0954, 0.4414, 0.4503],
    ["UNSW-NB15", "FGSM", 0.07, 0.2628, 0.3220, 0.2220, -0.5860, 0.1723, 0.1971],

    # PGD
    ["UNSW-NB15", "PGD", 0.01, 0.8384, 0.8368, 0.8400, 0.5507, 0.7099, 0.7750],
    ["UNSW-NB15", "PGD", 0.03, 0.5869, 0.6733, 0.5201, 0.0705, 0.5532, 0.5367],
    ["UNSW-NB15", "PGD", 0.05, 0.0521, 0.0735, 0.0404, -0.8665, 0.0984, 0.0694],
    ["UNSW-NB15", "PGD", 0.07, 0.0004, 0.0005, 0.0003, -0.9994, 0.0003, 0.0003],

    # MI-FGSM
    ["UNSW-NB15", "MI-FGSM", 0.01, 0.8386, 0.8364, 0.8407, 0.5507, 0.7089, 0.7748],
    ["UNSW-NB15", "MI-FGSM", 0.03, 0.5935, 0.6786, 0.5274, 0.0818, 0.5578, 0.5426],
    ["UNSW-NB15", "MI-FGSM", 0.05, 0.0658, 0.0912, 0.0515, -0.8565, 0.0922, 0.0718],
    ["UNSW-NB15", "MI-FGSM", 0.07, 0.0006, 0.0008, 0.0005, -0.9992, 0.0003, 0.0004],


    # FGSM
    ["NSL-KDD", "FGSM", 0.01, 0.9467, 0.9529, 0.9405, 0.8979, 0.9568, 0.9487],
    ["NSL-KDD", "FGSM", 0.03, 0.6861, 0.6170, 0.7726, 0.3347, 0.5552, 0.6639],
    ["NSL-KDD", "FGSM", 0.05, 0.3708, 0.3095, 0.4624, -0.5496, 0.0432, 0.2528],
    ["NSL-KDD", "FGSM", 0.07, 0.3101, 0.2621, 0.3795, -0.6646, 0.0091, 0.1943],

    # PGD
    ["NSL-KDD", "PGD", 0.01, 0.9380, 0.9447, 0.9314, 0.8814, 0.9494, 0.9404],
    ["NSL-KDD", "PGD", 0.03, 0.5586, 0.4830, 0.6621, 0.0050, 0.3426, 0.5024],
    ["NSL-KDD", "PGD", 0.05, 0.1705, 0.1534, 0.1920, -0.8077, 0.0169, 0.1044],
    ["NSL-KDD", "PGD", 0.07, 0.0998, 0.0919, 0.1091, -0.8994, 0.0000, 0.0546],

    # MI-FGSM
    ["NSL-KDD", "MI-FGSM", 0.01, 0.9384, 0.9447, 0.9321, 0.8820, 0.9494, 0.9408],
    ["NSL-KDD", "MI-FGSM", 0.03, 0.5504, 0.4808, 0.6436, -0.0012, 0.3553, 0.4994],
    ["NSL-KDD", "MI-FGSM", 0.05, 0.1663, 0.1498, 0.1868, -0.8122, 0.0169, 0.1018],
    ["NSL-KDD", "MI-FGSM", 0.07, 0.0961, 0.0887, 0.1049, -0.9031, 0.0000, 0.0525]
]

adv_cnn = [

    # FGSM
    ["UNSW-NB15", "FGSM", 0.01, 0.9194, 0.9395, 0.9001, 0.7860, 0.8973, 0.8987],
    ["UNSW-NB15", "FGSM", 0.03, 0.9031, 0.9177, 0.8890, 0.7397, 0.8589, 0.8739],
    ["UNSW-NB15", "FGSM", 0.05, 0.8872, 0.8991, 0.8757, 0.6952, 0.8261, 0.8509],
    ["UNSW-NB15", "FGSM", 0.07, 0.8674, 0.8822, 0.8530, 0.6439, 0.7984, 0.8257],

    # PGD
    ["UNSW-NB15", "PGD", 0.01, 0.9178, 0.9375, 0.8989, 0.7816, 0.8938, 0.8964],
    ["UNSW-NB15", "PGD", 0.03, 0.8946, 0.9087, 0.8810, 0.7165, 0.8433, 0.8621],
    ["UNSW-NB15", "PGD", 0.05, 0.8520, 0.8582, 0.8459, 0.5952, 0.7524, 0.7992],
    ["UNSW-NB15", "PGD", 0.07, 0.7325, 0.7723, 0.6967, 0.3236, 0.6363, 0.6665],

    # MI-FGSM
    ["UNSW-NB15", "MI-FGSM", 0.01, 0.9174, 0.9373, 0.8983, 0.7806, 0.8935, 0.8959],
    ["UNSW-NB15", "MI-FGSM", 0.03, 0.8941, 0.9084, 0.8802, 0.7151, 0.8427, 0.8615],
    ["UNSW-NB15", "MI-FGSM", 0.05, 0.8509, 0.8543, 0.8476, 0.5899, 0.7441, 0.7958],
    ["UNSW-NB15", "MI-FGSM", 0.07, 0.7436, 0.7809, 0.7097, 0.3475, 0.6473, 0.6785],

    # FGSM
    ["NSL-KDD", "FGSM", 0.01, 0.9790, 0.9865, 0.9717, 0.9600, 0.9877, 0.9797],
    ["NSL-KDD", "FGSM", 0.03, 0.9690, 0.9820, 0.9563, 0.9412, 0.9838, 0.9700],
    ["NSL-KDD", "FGSM", 0.05, 0.9554, 0.9708, 0.9405, 0.9157, 0.9737, 0.9571],
    ["NSL-KDD", "FGSM", 0.07, 0.9260, 0.9418, 0.9108, 0.8600, 0.9478, 0.9293],

    # PGD
    ["NSL-KDD", "PGD", 0.01, 0.9769, 0.9844, 0.9696, 0.9559, 0.9857, 0.9776],
    ["NSL-KDD", "PGD", 0.03, 0.9628, 0.9746, 0.9514, 0.9294, 0.9770, 0.9642],
    ["NSL-KDD", "PGD", 0.05, 0.9369, 0.9500, 0.9241, 0.8802, 0.9549, 0.9395],
    ["NSL-KDD", "PGD", 0.07, 0.8790, 0.8851, 0.8730, 0.7684, 0.8949, 0.8840],

    # MI-FGSM
    ["NSL-KDD", "MI-FGSM", 0.01, 0.9769, 0.9844, 0.9696, 0.9559, 0.9857, 0.9776],
    ["NSL-KDD", "MI-FGSM", 0.03, 0.9630, 0.9749, 0.9514, 0.9297, 0.9773, 0.9643],
    ["NSL-KDD", "MI-FGSM", 0.05, 0.9380, 0.9501, 0.9262, 0.8822, 0.9549, 0.9405],
    ["NSL-KDD", "MI-FGSM", 0.07, 0.8782, 0.8816, 0.8748, 0.7660, 0.8910, 0.8829]
]


gan_cnn = [
    # FGSM
    ["UNSW-NB15", "FGSM", 0.01, 0.9261, 0.9262, 0.9261, 0.7954, 0.8694, 0.8977],
    ["UNSW-NB15", "FGSM", 0.03, 0.9161, 0.9126, 0.9197, 0.7661, 0.8441, 0.8819],
    ["UNSW-NB15", "FGSM", 0.05, 0.9018, 0.9010, 0.9025, 0.7275, 0.8245, 0.8635],
    ["UNSW-NB15", "FGSM", 0.07, 0.8946, 0.8748, 0.9153, 0.6972, 0.7680, 0.8416],

    # PGD
    ["UNSW-NB15", "PGD", 0.01, 0.9259, 0.9263, 0.9255, 0.7948, 0.8696, 0.8975],
    ["UNSW-NB15", "PGD", 0.03, 0.9165, 0.9175, 0.9154, 0.7691, 0.8543, 0.8849],
    ["UNSW-NB15", "PGD", 0.05, 0.9004, 0.8965, 0.9044, 0.7219, 0.8151, 0.8597],
    ["UNSW-NB15", "PGD", 0.07, 0.8638, 0.8632, 0.8643, 0.6221, 0.7575, 0.8109],

    # MI-FGSM
    ["UNSW-NB15", "MI-FGSM", 0.01, 0.9242, 0.9262, 0.9223, 0.7909, 0.8699, 0.8961],
    ["UNSW-NB15", "MI-FGSM", 0.03, 0.9146, 0.9144, 0.9148, 0.7634, 0.8484, 0.8816],
    ["UNSW-NB15", "MI-FGSM", 0.05, 0.8986, 0.8967, 0.9004, 0.7180, 0.8164, 0.8584],
    ["UNSW-NB15", "MI-FGSM", 0.07, 0.8580, 0.8566, 0.8594, 0.6054, 0.7452, 0.8023],

    # FGSM
    ["NSL-KDD", "FGSM", 0.01, 0.9701, 0.9884, 0.9524, 0.9439, 0.9896, 0.9710],
    ["NSL-KDD", "FGSM", 0.03, 0.9648, 0.9851, 0.9454, 0.9342, 0.9867, 0.9661],
    ["NSL-KDD", "FGSM", 0.05, 0.9495, 0.9774, 0.9231, 0.9064, 0.9802, 0.9516],
    ["NSL-KDD", "FGSM", 0.07, 0.9399, 0.9612, 0.9196, 0.8873, 0.9656, 0.9426],

    # PGD
    ["NSL-KDD", "PGD", 0.01, 0.9701, 0.9884, 0.9524, 0.9439, 0.9896, 0.9710],
    ["NSL-KDD", "PGD", 0.03, 0.9646, 0.9861, 0.9440, 0.9339, 0.9877, 0.9659],
    ["NSL-KDD", "PGD", 0.05, 0.9520, 0.9789, 0.9265, 0.9110, 0.9815, 0.9540],
    ["NSL-KDD", "PGD", 0.07, 0.9365, 0.9641, 0.9105, 0.8820, 0.9685, 0.9395],

    # MI-FGSM
    ["NSL-KDD", "MI-FGSM", 0.01, 0.9703, 0.9884, 0.9528, 0.9442, 0.9896, 0.9712],
    ["NSL-KDD", "MI-FGSM", 0.03, 0.9639, 0.9850, 0.9437, 0.9326, 0.9867, 0.9652],
    ["NSL-KDD", "MI-FGSM", 0.05, 0.9471, 0.9755, 0.9203, 0.9020, 0.9786, 0.9494],
    ["NSL-KDD", "MI-FGSM", 0.07, 0.9331, 0.9546, 0.9126, 0.8745, 0.9598, 0.9362]
]


# Create DataFrame
df_cnn = pd.DataFrame(gan_cnn, columns=[
    "Dataset", "Attack", "Epsilon", "F1", "Precision", "Recall", "MCC", "Specificity", "Balanced_Acc"
])

# %%
clean_results_bilstm_nsl= {
    'f1': 0.9833596076370642, 
    'precision': 0.9849122807017544, 
    'recall': 0.9818118223154949, 
    'mcc': 0.9679745377873209, 
    'specificity': 0.9860480207657045, 
    'balanced_accuracy': 0.9839299215405997
}
clean_results_bilstm_unsw = {
    'f1': 0.9307509881422924, 
    'precision': 0.970971466270823, 
    'recall': 0.8937300743889479, 
    'mcc': 0.8259786978136132, 
    'specificity': 0.9526881720429852, 
    'balanced_accuracy': 0.9232091232159665
}

normal_bilstm = [
    # FGSM
    ["UNSW-NB15","FGSM", 0.01, 0.7930, 0.8433, 0.7483, 0.4866, 0.7538, 0.7510],
    ["UNSW-NB15","FGSM", 0.03, 0.8141, 0.7369, 0.9094, 0.3934, 0.4250, 0.6672],
    ["UNSW-NB15","FGSM", 0.05, 0.7341, 0.6463, 0.8494, 0.0344, 0.1769, 0.5131],
    ["UNSW-NB15","FGSM", 0.07, 0.6921, 0.6111, 0.7978, -0.1306, 0.1011, 0.4494],

    # PGD
    ["UNSW-NB15","PGD", 0.01, 0.4872, 0.6897, 0.3767, 0.0772, 0.7000, 0.5383],
    ["UNSW-NB15","PGD", 0.03, 0.2184, 0.2883, 0.1758, -0.5837, 0.2315, 0.2036],
    ["UNSW-NB15","PGD", 0.05, 0.2019, 0.2422, 0.1731, -0.7574, 0.0414, 0.1072],
    ["UNSW-NB15","PGD", 0.07, 0.2162, 0.2542, 0.1881, -0.7593, 0.0226, 0.1053],

    # MI-FGSM
    ["UNSW-NB15","MI-FGSM", 0.01, 0.6430, 0.7718, 0.5511, 0.2532, 0.7116, 0.6313],
    ["UNSW-NB15","MI-FGSM", 0.03, 0.2252, 0.2960, 0.1817, -0.5740, 0.2347, 0.2082],
    ["UNSW-NB15","MI-FGSM", 0.05, 0.1308, 0.1653, 0.1082, -0.8368, 0.0323, 0.0703],
    ["UNSW-NB15","MI-FGSM", 0.07, 0.1801, 0.2159, 0.1545, -0.8093, 0.0059, 0.0802],
    # FGSM
    ["NSL-KDD", "FGSM", 0.01, 0.8948, 0.8850, 0.9049, 0.7954, 0.8910, 0.8979],
    ["NSL-KDD", "FGSM", 0.03, 0.6634, 0.5479, 0.8409, 0.2241, 0.3563, 0.5986],
    ["NSL-KDD", "FGSM", 0.05, 0.6489, 0.5819, 0.7335, 0.2501, 0.5110, 0.6223],
    ["NSL-KDD", "FGSM", 0.07, 0.6204, 0.5745, 0.6744, 0.2127, 0.5367, 0.6055],

    # PGD
    ["NSL-KDD", "PGD", 0.01, 0.8436, 0.8284, 0.8594, 0.6938, 0.8348, 0.8471],
    ["NSL-KDD", "PGD", 0.03, 0.5635, 0.4722, 0.6985, -0.0284, 0.2758, 0.4871],
    ["NSL-KDD", "PGD", 0.05, 0.4043, 0.3519, 0.4750, -0.3524, 0.1885, 0.3318],
    ["NSL-KDD", "PGD", 0.07, 0.2134, 0.2017, 0.2267, -0.6072, 0.1677, 0.1972],

    # MI-FGSM
    ["NSL-KDD", "MI-FGSM", 0.01, 0.8526, 0.8416, 0.8639, 0.7126, 0.8491, 0.8565],
    ["NSL-KDD", "MI-FGSM", 0.03, 0.5533, 0.4560, 0.7034, -0.0857, 0.2216, 0.4625],
    ["NSL-KDD", "MI-FGSM", 0.05, 0.4109, 0.3473, 0.5030, -0.4067, 0.1230, 0.3130],
    ["NSL-KDD", "MI-FGSM", 0.07, 0.1944, 0.1752, 0.2183, -0.7491, 0.0470, 0.1327],
]

adv_bilstm = [
    # FGSM
    ["UNSW-NB15","FGSM", 0.01, 0.9288, 0.9589, 0.9004, 0.8158, 0.9317, 0.9161],
    ["UNSW-NB15","FGSM", 0.03, 0.9178, 0.9483, 0.8892, 0.7874, 0.9142, 0.9017],
    ["UNSW-NB15","FGSM", 0.05, 0.8640, 0.9088, 0.8234, 0.6588, 0.8538, 0.8386],
    ["UNSW-NB15","FGSM", 0.07, 0.8203, 0.8856, 0.7639, 0.5689, 0.8253, 0.7946],

    # PGD
    ["UNSW-NB15","PGD", 0.01, 0.9286, 0.9588, 0.9003, 0.8154, 0.9315, 0.9159],
    ["UNSW-NB15","PGD", 0.03, 0.9152, 0.9453, 0.8869, 0.7803, 0.9091, 0.8980],
    ["UNSW-NB15","PGD", 0.05, 0.8193, 0.8894, 0.7594, 0.5712, 0.8328, 0.7961],
    ["UNSW-NB15","PGD", 0.07, 0.7574, 0.8407, 0.6891, 0.4403, 0.7688, 0.7290],

    # MI-FGSM
    ["UNSW-NB15","MI-FGSM", 0.01, 0.9287, 0.9589, 0.9003, 0.8156, 0.9317, 0.9160],
    ["UNSW-NB15","MI-FGSM", 0.03, 0.9156, 0.9458, 0.8874, 0.7815, 0.9099, 0.8987],
    ["UNSW-NB15","MI-FGSM", 0.05, 0.8322, 0.8953, 0.7774, 0.5957, 0.8390, 0.8082],
    ["UNSW-NB15","MI-FGSM", 0.07, 0.7750, 0.8522, 0.7106, 0.4740, 0.7817, 0.7462],

    # FGSM
    ["NSL-KDD", "FGSM", 0.01, 0.9872, 0.9867, 0.9878, 0.9754, 0.9877, 0.9877],
    ["NSL-KDD", "FGSM", 0.03, 0.9839, 0.9832, 0.9846, 0.9690, 0.9844, 0.9845],
    ["NSL-KDD", "FGSM", 0.05, 0.9775, 0.9763, 0.9787, 0.9565, 0.9779, 0.9783],
    ["NSL-KDD", "FGSM", 0.07, 0.9662, 0.9625, 0.9699, 0.9346, 0.9650, 0.9674],

    # PGD
    ["NSL-KDD", "PGD", 0.01, 0.9872, 0.9867, 0.9878, 0.9754, 0.9877, 0.9877],
    ["NSL-KDD", "PGD", 0.03, 0.9825, 0.9818, 0.9832, 0.9663, 0.9831, 0.9832],
    ["NSL-KDD", "PGD", 0.05, 0.9747, 0.9735, 0.9759, 0.9511, 0.9753, 0.9756],
    ["NSL-KDD", "PGD", 0.07, 0.9354, 0.9362, 0.9346, 0.8756, 0.9409, 0.9378],

    # MI-FGSM
    ["NSL-KDD", "MI-FGSM", 0.01, 0.9872, 0.9867, 0.9878, 0.9754, 0.9877, 0.9877],
    ["NSL-KDD", "MI-FGSM", 0.03, 0.9825, 0.9818, 0.9832, 0.9663, 0.9831, 0.9832],
    ["NSL-KDD", "MI-FGSM", 0.05, 0.9757, 0.9749, 0.9766, 0.9531, 0.9766, 0.9766],
    ["NSL-KDD", "MI-FGSM", 0.07, 0.9469, 0.9462, 0.9475, 0.8975, 0.9500, 0.9488],
]


gan_bilstm = [

    # FGSM
    ["UNSW-NB15","FGSM", 0.01, 0.9279, 0.9409, 0.9153, 0.8055, 0.8981, 0.9067],
    ["UNSW-NB15","FGSM", 0.03, 0.9209, 0.9329, 0.9092, 0.7862, 0.8841, 0.8967],
    ["UNSW-NB15","FGSM", 0.05, 0.9095, 0.9216, 0.8977, 0.7554, 0.8648, 0.8812],
    ["UNSW-NB15","FGSM", 0.07, 0.8829, 0.9021, 0.8646, 0.6885, 0.8339, 0.8492],


    # PGD
    ["UNSW-NB15","PGD", 0.01, 0.9278, 0.9406, 0.9154, 0.8053, 0.8976, 0.9065],
    ["UNSW-NB15","PGD", 0.03, 0.9203, 0.9320, 0.9089, 0.7844, 0.8825, 0.8957],
    ["UNSW-NB15","PGD", 0.05, 0.9077, 0.9219, 0.8939, 0.7516, 0.8659, 0.8799],
    ["UNSW-NB15","PGD", 0.07, 0.8857, 0.9103, 0.8625, 0.6996, 0.8495, 0.8560],


    # MI-FGSM
    ["UNSW-NB15","MI-FGSM", 0.01, 0.9277, 0.9407, 0.9151, 0.8051, 0.8978, 0.9065],
    ["UNSW-NB15","MI-FGSM", 0.03, 0.9203, 0.9316, 0.9094, 0.7843, 0.8817, 0.8955],
    ["UNSW-NB15","MI-FGSM", 0.05, 0.9084, 0.9213, 0.8959, 0.7529, 0.8645, 0.8802],
    ["UNSW-NB15","MI-FGSM", 0.07, 0.8759, 0.9050, 0.8486, 0.6771, 0.8422, 0.8454],

    # FGSM
    ["NSL-KDD", "FGSM", 0.01, 0.9848, 0.9846, 0.9850, 0.9707, 0.9857, 0.9853],
    ["NSL-KDD", "FGSM", 0.03, 0.9792, 0.9797, 0.9787, 0.9599, 0.9812, 0.9799],
    ["NSL-KDD", "FGSM", 0.05, 0.9724, 0.9727, 0.9720, 0.9467, 0.9747, 0.9734],
    ["NSL-KDD", "FGSM", 0.07, 0.9605, 0.9647, 0.9563, 0.9242, 0.9676, 0.9619],

    # PGD
    ["NSL-KDD", "PGD", 0.01, 0.9844, 0.9839, 0.9850, 0.9700, 0.9851, 0.9850],
    ["NSL-KDD", "PGD", 0.03, 0.9757, 0.9749, 0.9766, 0.9531, 0.9766, 0.9766],
    ["NSL-KDD", "PGD", 0.05, 0.9696, 0.9686, 0.9706, 0.9413, 0.9708, 0.9707],
    ["NSL-KDD", "PGD", 0.07, 0.9613, 0.9631, 0.9594, 0.9255, 0.9659, 0.9627],

    # MI-FGSM
    ["NSL-KDD", "MI-FGSM", 0.01, 0.9848, 0.9846, 0.9850, 0.9707, 0.9857, 0.9853],
    ["NSL-KDD", "MI-FGSM", 0.03, 0.9778, 0.9776, 0.9780, 0.9572, 0.9792, 0.9786],
    ["NSL-KDD", "MI-FGSM", 0.05, 0.9722, 0.9707, 0.9738, 0.9464, 0.9727, 0.9733],
    ["NSL-KDD", "MI-FGSM", 0.07, 0.9570, 0.9605, 0.9535, 0.9174, 0.9637, 0.9586],
]




# Create DataFrame
df_adv = pd.DataFrame(gan_bilstm, columns=[
    "Dataset", "Attack", "Epsilon", "F1", "Precision", "Recall", "MCC", "Specificity", "Balanced_Acc"
])

# %% [markdown]
# ## UNSW-NB15

# %%
clear_results_cnn= {
    'f1': 0.9481302774427021, 
    'precision': 0.9417403025310769, 
    'recall': 0.9546075603461364, 
    'mcc': 0.85469167173334, 
    'specificity': 0.8954301075268576, 
    'balanced_accuracy': 0.925018833936497
}

normal_cnn = [
    
    # FGSM
    ["UNSW-NB15", "FGSM", 0.01, 0.8528, 0.8419, 0.8640, 0.5829, 0.7126, 0.7883],
    ["UNSW-NB15", "FGSM", 0.03, 0.7007, 0.7606, 0.6496, 0.2773, 0.6379, 0.6438],
    ["UNSW-NB15", "FGSM", 0.05, 0.5175, 0.5928, 0.4592, -0.0954, 0.4414, 0.4503],
    ["UNSW-NB15", "FGSM", 0.07, 0.2628, 0.3220, 0.2220, -0.5860, 0.1723, 0.1971],

    # PGD
    ["UNSW-NB15", "PGD", 0.01, 0.8384, 0.8368, 0.8400, 0.5507, 0.7099, 0.7750],
    ["UNSW-NB15", "PGD", 0.03, 0.5869, 0.6733, 0.5201, 0.0705, 0.5532, 0.5367],
    ["UNSW-NB15", "PGD", 0.05, 0.0521, 0.0735, 0.0404, -0.8665, 0.0984, 0.0694],
    ["UNSW-NB15", "PGD", 0.07, 0.0004, 0.0005, 0.0003, -0.9994, 0.0003, 0.0003],

    # MI-FGSM
    ["UNSW-NB15", "MI-FGSM", 0.01, 0.8386, 0.8364, 0.8407, 0.5507, 0.7089, 0.7748],
    ["UNSW-NB15", "MI-FGSM", 0.03, 0.5935, 0.6786, 0.5274, 0.0818, 0.5578, 0.5426],
    ["UNSW-NB15", "MI-FGSM", 0.05, 0.0658, 0.0912, 0.0515, -0.8565, 0.0922, 0.0718],
    ["UNSW-NB15", "MI-FGSM", 0.07, 0.0006, 0.0008, 0.0005, -0.9992, 0.0003, 0.0004],
]

adv_cnn = [
    # Clean
    ["UNSW-NB15", "Clean", 0.00, 0.9371, 0.9640, 0.9116, 0.8362, 0.9398, 0.9257],

    # FGSM
    ["UNSW-NB15", "FGSM", 0.01, 0.9194, 0.9395, 0.9001, 0.7860, 0.8973, 0.8987],
    ["UNSW-NB15", "FGSM", 0.03, 0.9031, 0.9177, 0.8890, 0.7397, 0.8589, 0.8739],
    ["UNSW-NB15", "FGSM", 0.05, 0.8872, 0.8991, 0.8757, 0.6952, 0.8261, 0.8509],
    ["UNSW-NB15", "FGSM", 0.07, 0.8674, 0.8822, 0.8530, 0.6439, 0.7984, 0.8257],

    # PGD
    ["UNSW-NB15", "PGD", 0.01, 0.9178, 0.9375, 0.8989, 0.7816, 0.8938, 0.8964],
    ["UNSW-NB15", "PGD", 0.03, 0.8946, 0.9087, 0.8810, 0.7165, 0.8433, 0.8621],
    ["UNSW-NB15", "PGD", 0.05, 0.8520, 0.8582, 0.8459, 0.5952, 0.7524, 0.7992],
    ["UNSW-NB15", "PGD", 0.07, 0.7325, 0.7723, 0.6967, 0.3236, 0.6363, 0.6665],

    # MI-FGSM
    ["UNSW-NB15", "MI-FGSM", 0.01, 0.9174, 0.9373, 0.8983, 0.7806, 0.8935, 0.8959],
    ["UNSW-NB15", "MI-FGSM", 0.03, 0.8941, 0.9084, 0.8802, 0.7151, 0.8427, 0.8615],
    ["UNSW-NB15", "MI-FGSM", 0.05, 0.8509, 0.8543, 0.8476, 0.5899, 0.7441, 0.7958],
    ["UNSW-NB15", "MI-FGSM", 0.07, 0.7436, 0.7809, 0.7097, 0.3475, 0.6473, 0.6785],
]

gan_cnn = [
    
    # FGSM
    ["UNSW-NB15", "FGSM", 0.01, 0.9261, 0.9262, 0.9261, 0.7954, 0.8694, 0.8977],
    ["UNSW-NB15", "FGSM", 0.03, 0.9161, 0.9126, 0.9197, 0.7661, 0.8441, 0.8819],
    ["UNSW-NB15", "FGSM", 0.05, 0.9018, 0.9010, 0.9025, 0.7275, 0.8245, 0.8635],
    ["UNSW-NB15", "FGSM", 0.07, 0.8946, 0.8748, 0.9153, 0.6972, 0.7680, 0.8416],

    # PGD
    ["UNSW-NB15", "PGD", 0.01, 0.9259, 0.9263, 0.9255, 0.7948, 0.8696, 0.8975],
    ["UNSW-NB15", "PGD", 0.03, 0.9165, 0.9175, 0.9154, 0.7691, 0.8543, 0.8849],
    ["UNSW-NB15", "PGD", 0.05, 0.9004, 0.8965, 0.9044, 0.7219, 0.8151, 0.8597],
    ["UNSW-NB15", "PGD", 0.07, 0.8638, 0.8632, 0.8643, 0.6221, 0.7575, 0.8109],

    # MI-FGSM
    ["UNSW-NB15", "MI-FGSM", 0.01, 0.9242, 0.9262, 0.9223, 0.7909, 0.8699, 0.8961],
    ["UNSW-NB15", "MI-FGSM", 0.03, 0.9146, 0.9144, 0.9148, 0.7634, 0.8484, 0.8816],
    ["UNSW-NB15", "MI-FGSM", 0.05, 0.8986, 0.8967, 0.9004, 0.7180, 0.8164, 0.8584],
    ["UNSW-NB15", "MI-FGSM", 0.07, 0.8580, 0.8566, 0.8594, 0.6054, 0.7452, 0.8023]
]

# %%
clean_results_lstm = {
    'f1': 0.9315194835139496, 
    'precision': 0.9433374844333748, 
    'recall': 0.9199939274328223, 
    'mcc': 0.8148487010682461, 
    'specificity': 0.9021505376343844, 
    'balanced_accuracy': 0.9110722325336034
}

normal_lstm = [
    # FGSM
    ["UNSW-NB15","FGSM", 0.01, 0.8096, 0.8292, 0.7910, 0.4947, 0.7116, 0.7513],
    ["UNSW-NB15","FGSM", 0.03, 0.4563, 0.6077, 0.3653, -0.0516, 0.5825, 0.4739],
    ["UNSW-NB15","FGSM", 0.05, 0.3298, 0.4729, 0.2532, -0.2495, 0.5003, 0.3767],
    ["UNSW-NB15","FGSM", 0.07, 0.2853, 0.3705, 0.2320, -0.4567, 0.3022, 0.2671],

    # PGD
    ["UNSW-NB15","PGD", 0.01, 0.7876, 0.8066, 0.7694, 0.4359, 0.6734, 0.7214],
    ["UNSW-NB15","PGD", 0.03, 0.0897, 0.1822, 0.0595, -0.4887, 0.5269, 0.2932],
    ["UNSW-NB15","PGD", 0.05, 0.0710, 0.1393, 0.0477, -0.5505, 0.4785, 0.2631],
    ["UNSW-NB15","PGD", 0.07, 0.0483, 0.0871, 0.0334, -0.6551, 0.3798, 0.2066],

    # MI-FGSM
    ["UNSW-NB15","MI-FGSM", 0.01, 0.7921, 0.8115, 0.7736, 0.4482, 0.6817, 0.7277],
    ["UNSW-NB15","MI-FGSM", 0.03, 0.0973, 0.1952, 0.0648, -0.4798, 0.5266, 0.2957],
    ["UNSW-NB15","MI-FGSM", 0.05, 0.0698, 0.1373, 0.0468, -0.5512, 0.4796, 0.2632],
    ["UNSW-NB15","MI-FGSM", 0.07, 0.0491, 0.0800, 0.0354, -0.7303, 0.2801, 0.1577],
]

adv_lstm = [

    # FGSM
    ["UNSW-NB15","FGSM", 0.01, 0.9217, 0.8570, 0.9970, 0.7724, 0.7054, 0.8512],
    ["UNSW-NB15","FGSM", 0.03, 0.9204, 0.8565, 0.9947, 0.7681, 0.7048, 0.8498],
    ["UNSW-NB15","FGSM", 0.05, 0.9169, 0.8528, 0.9913, 0.7565, 0.6970, 0.8442],
    ["UNSW-NB15","FGSM", 0.07, 0.8594, 0.7854, 0.9487, 0.5606, 0.5411, 0.7449],

    # PGD
    ["UNSW-NB15","PGD", 0.01, 0.9217, 0.8570, 0.9970, 0.7724, 0.7054, 0.8512],
    ["UNSW-NB15","PGD", 0.03, 0.9204, 0.8565, 0.9947, 0.7681, 0.7048, 0.8498],
    ["UNSW-NB15","PGD", 0.05, 0.9099, 0.8459, 0.9844, 0.7336, 0.6825, 0.8334],
    ["UNSW-NB15","PGD", 0.07, 0.8320, 0.7526, 0.9302, 0.4583, 0.4586, 0.6944],

    # MI-FGSM
    ["UNSW-NB15","MI-FGSM", 0.01, 0.9217, 0.8570, 0.9970, 0.7724, 0.7054, 0.8512],
    ["UNSW-NB15","MI-FGSM", 0.03, 0.9204, 0.8565, 0.9947, 0.7681, 0.7048, 0.8498],
    ["UNSW-NB15","MI-FGSM", 0.05, 0.9123, 0.8483, 0.9868, 0.7416, 0.6876, 0.8372],
    ["UNSW-NB15","MI-FGSM", 0.07, 0.8363, 0.7587, 0.9315, 0.4756, 0.4755, 0.7035],
]

gan_lstm = [

    # FGSM
    ["UNSW-NB15","FGSM", 0.01, 0.9200, 0.8540, 0.9971, 0.7672, 0.6981, 0.8476],
    ["UNSW-NB15","FGSM", 0.03, 0.9195, 0.8535, 0.9967, 0.7657, 0.6970, 0.8469],
    ["UNSW-NB15","FGSM", 0.05, 0.9167, 0.8505, 0.9941, 0.7564, 0.6906, 0.8423],
    ["UNSW-NB15","FGSM", 0.07, 0.9116, 0.8478, 0.9857, 0.7390, 0.6866, 0.8361],

    # PGD
    ["UNSW-NB15","PGD", 0.01, 0.9200, 0.8540, 0.9971, 0.7672, 0.6981, 0.8476],
    ["UNSW-NB15","PGD", 0.03, 0.9194, 0.8534, 0.9965, 0.7652, 0.6968, 0.8466],
    ["UNSW-NB15","PGD", 0.05, 0.9159, 0.8496, 0.9933, 0.7536, 0.6887, 0.8410],
    ["UNSW-NB15","PGD", 0.07, 0.9088, 0.8430, 0.9857, 0.7302, 0.6750, 0.8304],

    # MI-FGSM
    ["UNSW-NB15","MI-FGSM", 0.01, 0.9200, 0.8540, 0.9971, 0.7672, 0.6981, 0.8476],
    ["UNSW-NB15","MI-FGSM", 0.03, 0.9195, 0.8537, 0.9964, 0.7655, 0.6976, 0.8470],
    ["UNSW-NB15","MI-FGSM", 0.05, 0.9165, 0.8500, 0.9944, 0.7559, 0.6892, 0.8418],
    ["UNSW-NB15","MI-FGSM", 0.07, 0.9103, 0.8461, 0.9850, 0.7348, 0.6828, 0.8339],
]

# %%
normal_bilstm = {
    'f1': 0.9307509881422924, 
    'precision': 0.970971466270823, 
    'recall': 0.8937300743889479, 
    'mcc': 0.8259786978136132, 
    'specificity': 0.9526881720429852, 
    'balanced_accuracy': 0.9232091232159665
}

normal_bilstm = [

    # FGSM
    ["UNSW-NB15","FGSM", 0.01, 0.7930, 0.8433, 0.7483, 0.4866, 0.7538, 0.7510],
    ["UNSW-NB15","FGSM", 0.03, 0.8141, 0.7369, 0.9094, 0.3934, 0.4250, 0.6672],
    ["UNSW-NB15","FGSM", 0.05, 0.7341, 0.6463, 0.8494, 0.0344, 0.1769, 0.5131],
    ["UNSW-NB15","FGSM", 0.07, 0.6921, 0.6111, 0.7978, -0.1306, 0.1011, 0.4494],

    # PGD
    ["UNSW-NB15","PGD", 0.01, 0.4872, 0.6897, 0.3767, 0.0772, 0.7000, 0.5383],
    ["UNSW-NB15","PGD", 0.03, 0.2184, 0.2883, 0.1758, -0.5837, 0.2315, 0.2036],
    ["UNSW-NB15","PGD", 0.05, 0.2019, 0.2422, 0.1731, -0.7574, 0.0414, 0.1072],
    ["UNSW-NB15","PGD", 0.07, 0.2162, 0.2542, 0.1881, -0.7593, 0.0226, 0.1053],

    # MI-FGSM
    ["UNSW-NB15","MI-FGSM", 0.01, 0.6430, 0.7718, 0.5511, 0.2532, 0.7116, 0.6313],
    ["UNSW-NB15","MI-FGSM", 0.03, 0.2252, 0.2960, 0.1817, -0.5740, 0.2347, 0.2082],
    ["UNSW-NB15","MI-FGSM", 0.05, 0.1308, 0.1653, 0.1082, -0.8368, 0.0323, 0.0703],
    ["UNSW-NB15","MI-FGSM", 0.07, 0.1801, 0.2159, 0.1545, -0.8093, 0.0059, 0.0802],
]

adv_lstm = [
    
    # FGSM
    ["UNSW-NB15","FGSM", 0.01, 0.9288, 0.9589, 0.9004, 0.8158, 0.9317, 0.9161],
    ["UNSW-NB15","FGSM", 0.03, 0.9178, 0.9483, 0.8892, 0.7874, 0.9142, 0.9017],
    ["UNSW-NB15","FGSM", 0.05, 0.8640, 0.9088, 0.8234, 0.6588, 0.8538, 0.8386],
    ["UNSW-NB15","FGSM", 0.07, 0.8203, 0.8856, 0.7639, 0.5689, 0.8253, 0.7946],

    # PGD
    ["UNSW-NB15","PGD", 0.01, 0.9286, 0.9588, 0.9003, 0.8154, 0.9315, 0.9159],
    ["UNSW-NB15","PGD", 0.03, 0.9152, 0.9453, 0.8869, 0.7803, 0.9091, 0.8980],
    ["UNSW-NB15","PGD", 0.05, 0.8193, 0.8894, 0.7594, 0.5712, 0.8328, 0.7961],
    ["UNSW-NB15","PGD", 0.07, 0.7574, 0.8407, 0.6891, 0.4403, 0.7688, 0.7290],

    # MI-FGSM
    ["UNSW-NB15","MI-FGSM", 0.01, 0.9287, 0.9589, 0.9003, 0.8156, 0.9317, 0.9160],
    ["UNSW-NB15","MI-FGSM", 0.03, 0.9156, 0.9458, 0.8874, 0.7815, 0.9099, 0.8987],
    ["UNSW-NB15","MI-FGSM", 0.05, 0.8322, 0.8953, 0.7774, 0.5957, 0.8390, 0.8082],
    ["UNSW-NB15","MI-FGSM", 0.07, 0.7750, 0.8522, 0.7106, 0.4740, 0.7817, 0.7462],
]

gan_bilstm = [
    
    # FGSM
    ["UNSW-NB15","FGSM", 0.01, 0.9279, 0.9409, 0.9153, 0.8055, 0.8981, 0.9067],
    ["UNSW-NB15","FGSM", 0.03, 0.9209, 0.9329, 0.9092, 0.7862, 0.8841, 0.8967],
    ["UNSW-NB15","FGSM", 0.05, 0.9095, 0.9216, 0.8977, 0.7554, 0.8648, 0.8812],
    ["UNSW-NB15","FGSM", 0.07, 0.8829, 0.9021, 0.8646, 0.6885, 0.8339, 0.8492],

    # PGD
    ["UNSW-NB15","PGD", 0.01, 0.9278, 0.9406, 0.9154, 0.8053, 0.8976, 0.9065],
    ["UNSW-NB15","PGD", 0.03, 0.9203, 0.9320, 0.9089, 0.7844, 0.8825, 0.8957],
    ["UNSW-NB15","PGD", 0.05, 0.9077, 0.9219, 0.8939, 0.7516, 0.8659, 0.8799],
    ["UNSW-NB15","PGD", 0.07, 0.8857, 0.9103, 0.8625, 0.6996, 0.8495, 0.8560],

    # MI-FGSM
    ["UNSW-NB15","MI-FGSM", 0.01, 0.9277, 0.9407, 0.9151, 0.8051, 0.8978, 0.9065],
    ["UNSW-NB15","MI-FGSM", 0.03, 0.9203, 0.9316, 0.9094, 0.7843, 0.8817, 0.8955],
    ["UNSW-NB15","MI-FGSM", 0.05, 0.9084, 0.9213, 0.8959, 0.7529, 0.8645, 0.8802],
    ["UNSW-NB15","MI-FGSM", 0.07, 0.8759, 0.9050, 0.8486, 0.6771, 0.8422, 0.8454],
]
