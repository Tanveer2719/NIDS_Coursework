# %%
# !git clone https://github.com/Tanveer2719/NIDS_Coursework.git
# Out:
# Cloning into 'NIDS_Coursework'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 123 (delta 42), reused 118 (delta 37), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 141.67 KiB | 2.83 MiB/s, done.
# Resolving deltas: 100% (42/42), done.

# %%
# %cd /kaggle/working/NIDS_Coursework/My_Code
# !ls
# Out:
# /kaggle/working/NIDS_Coursework/My_Code
# classification.py    main.ipynb     record_level_embedding.py
# featureSelection.py  preprocess.py  transformer.py

# %%
# %rm -r __pycache__
# Out:
# rm: cannot remove '__pycache__': No such file or directory

# %%
# !git pull origin main
# Out:
# From https://github.com/Tanveer2719/NIDS_Coursework
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
import pandas as pd
import numpy as np

path = "/kaggle/input/unsw-nb-15/UNSW-NB15_combined.csv"

df = pd.read_csv(path)

print(df.shape)
df = df.drop(columns=['id', 'label'])
print(df.shape)

print(f"🧾 Unique class labels: {df['attack_cat'].unique()}")
df['label'] = df['attack_cat'].apply(lambda x: 0 if x == 'Normal' else 1)

print(f'Unique values for label {df["label"].unique()}')

df = df.drop(columns=["attack_cat"])
print(f'new shape{df.shape}')

print(df.dtypes)
# Out:
# (257673, 45)
# (257673, 43)
# 🧾 Unique class labels: ['Normal' 'Backdoor' 'Analysis' 'Fuzzers' 'Shellcode' 'Reconnaissance'
#  'Exploits' 'DoS' 'Worms' 'Generic']
# Unique values for label [0 1]
# new shape(257673, 43)
# dur                  float64
# proto                 object
# service               object
# state                 object
# spkts                  int64
# dpkts                  int64
# sbytes                 int64
# dbytes                 int64
# rate                 float64
# sttl                   int64
# dttl                   int64
# sload                float64
# dload                float64
# sloss                  int64
# dloss                  int64
# sinpkt               float64
# dinpkt               float64
# sjit                 float64
# djit                 float64
# swin                   int64
# stcpb                  int64
# dtcpb                  int64
# dwin                   int64
# tcprtt               float64
# synack               float64
# ackdat               float64
# smean                  int64
# dmean                  int64
# trans_depth            int64
# response_body_len      int64
# ct_srv_src             int64
# ct_state_ttl           int64
# ct_dst_ltm             int64
# ct_src_dport_ltm       int64
# ct_dst_sport_ltm       int64
# ct_dst_src_ltm         int64
# is_ftp_login           int64
# ct_ftp_cmd             int64
# ct_flw_http_mthd       int64
# ct_src_ltm             int64
# ct_srv_dst             int64
# is_sm_ips_ports        int64
# label                  int64
# dtype: object

# %%
# perform preprocessing

from preprocess import Preprocess

# separate the features and labels so that the labesl are not encoded
labels = df['label']
features = df.drop(columns=['label'])

pp = Preprocess()
processed_features = pp.fit_transform_df_auto(df = features,n_categorical_levels=32, expected_categorical_format='onehot')

print(processed_features.shape)
processed_features.head()
# Out:
# Encoding the 32 levels for proto
# Encoding the 13 levels for service
# Encoding the 11 levels for state
# (257673, 95)
#         dur     spkts     dpkts    sbytes    dbytes      rate      sttl  \
# 0  0.027889  0.193225  0.172921  0.331292  0.312312  0.312595  0.997874
# 1  0.121803  0.284598  0.393619  0.398471  0.645181  0.316704  0.747160
# 2  0.234590  0.224248  0.304405  0.353884  0.574953  0.196832  0.747160
# 3  0.239956  0.267974  0.275582  0.388675  0.402879  0.194440  0.747160
# 4  0.090294  0.248312  0.209072  0.378428  0.339064  0.256038  0.999294
#
#        dttl     sload     dload  ...  state_2  state_3  state_4  state_5  \
# 0  1.000000  0.424562  0.534539  ...    False    False    False    False
# 1  0.998579  0.401347  0.775718  ...    False    False    False    False
# 2  0.998579  0.326962  0.650937  ...    False    False    False    False
# 3  0.998579  0.351625  0.479722  ...    False    False    False    False
# 4  0.998579  0.402218  0.489854  ...    False    False    False    False
#
#    state_6  state_7  state_8  state_9  state_10  state_11
# 0    False    False    False    False     False     False
# 1    False    False    False    False     False     False
# 2    False    False    False    False     False     False
# 3    False    False    False    False     False     False
# 4    False    False    False    False     False     False
#
# [5 rows x 95 columns]

# %%
# concat the features and the labels
processed_full_df = pd.concat([processed_features, labels], axis=1)
processed_full_df.head()
# Out:
#         dur     spkts     dpkts    sbytes    dbytes      rate      sttl  \
# 0  0.027889  0.193225  0.172921  0.331292  0.312312  0.312595  0.997874
# 1  0.121803  0.284598  0.393619  0.398471  0.645181  0.316704  0.747160
# 2  0.234590  0.224248  0.304405  0.353884  0.574953  0.196832  0.747160
# 3  0.239956  0.267974  0.275582  0.388675  0.402879  0.194440  0.747160
# 4  0.090294  0.248312  0.209072  0.378428  0.339064  0.256038  0.999294
#
#        dttl     sload     dload  ...  state_3  state_4  state_5  state_6  \
# 0  1.000000  0.424562  0.534539  ...    False    False    False    False
# 1  0.998579  0.401347  0.775718  ...    False    False    False    False
# 2  0.998579  0.326962  0.650937  ...    False    False    False    False
# 3  0.998579  0.351625  0.479722  ...    False    False    False    False
# 4  0.998579  0.402218  0.489854  ...    False    False    False    False
#
#    state_7  state_8  state_9  state_10  state_11  label
# 0    False    False    False     False     False      0
# 1    False    False    False     False     False      0
# 2    False    False    False     False     False      0
# 3    False    False    False     False     False      0
# 4    False    False    False     False     False      0
#
# [5 rows x 96 columns]

# %%
from featureSelection import KBestFeatureSelector

kbest = KBestFeatureSelector(k=40)  # Set k to your desired number of features
selected_mask, selected_feature = kbest.select_features(df=processed_full_df, target_column='label', verbose=True)

selected_feature
# Out:
# 🔍 Starting SelectKBest feature selection (k = 40) using mutual_info_classif...
# ✅ Selected top 40 features out of 95
# 📌 Selected features:
#    1. dur
#    2. spkts
#    3. dpkts
#    4. sbytes
#    5. dbytes
#    6. rate
#    7. sttl
#    8. dttl
#    9. sload
#   10. dload
#   11. sloss
#   12. dloss
#   13. sinpkt
#   14. dinpkt
#   15. sjit
#   16. djit
#   17. swin
#   18. stcpb
#   19. dtcpb
#   20. dwin
#   21. tcprtt
#   22. synack
#   23. ackdat
#   24. smean
#   25. dmean
#   26. response_body_len
#   27. ct_srv_src
#   28. ct_state_ttl
#   29. ct_dst_ltm
#   30. ct_src_dport_ltm
#   31. ct_dst_sport_ltm
#   32. ct_dst_src_ltm
#   33. ct_src_ltm
#   34. ct_srv_dst
#   35. proto_1
#   36. service_1
#   37. service_2
#   38. state_1
#   39. state_2
#   40. state_3
# Index(['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl',
#        'sload', 'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit',
#        'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 'ackdat', 'smean',
#        'dmean', 'response_body_len', 'ct_srv_src', 'ct_state_ttl',
#        'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm',
#        'ct_src_ltm', 'ct_srv_dst', 'proto_1', 'service_1', 'service_2',
#        'state_1', 'state_2', 'state_3'],
#       dtype='object')

# %%
columns_to_keep = selected_feature

# %%
df_selected = processed_full_df[columns_to_keep].copy()
df_selected.shape
# Out:
# (257673, 40)

# %%
df_selected.dtypes
# Out:
# dur                  float64
# spkts                float64
# dpkts                float64
# sbytes               float64
# dbytes               float64
# rate                 float64
# sttl                 float64
# dttl                 float64
# sload                float64
# dload                float64
# sloss                float64
# dloss                float64
# sinpkt               float64
# dinpkt               float64
# sjit                 float64
# djit                 float64
# swin                 float64
# stcpb                float64
# dtcpb                float64
# dwin                 float64
# tcprtt               float64
# synack               float64
# ackdat               float64
# smean                float64
# dmean                float64
# response_body_len    float64
# ct_srv_src           float64
# ct_state_ttl         float64
# ct_dst_ltm           float64
# ct_src_dport_ltm     float64
# ct_dst_sport_ltm     float64
# ct_dst_src_ltm       float64
# ct_src_ltm           float64
# ct_srv_dst           float64
# proto_1                 bool
# service_1               bool
# service_2               bool
# state_1                 bool
# state_2                 bool
# state_3                 bool
# dtype: object

# %%
numerical_columns = [col for col in columns_to_keep 
                     if not (col.startswith("proto_") or 
                             col.startswith("service_") or 
                             col.startswith("state_"))]

# %%
from record_level_embedding import RecordLevelEmbedder

embedder = RecordLevelEmbedder(selected_df = df_selected, numerical_columns = numerical_columns, embed_dimension= 64)

embedded_df = embedder.transform_to_df()

embedded_df.head()
# Out:
# 2025-07-18 17:01:45.662479: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752858106.025603      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752858106.133242      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [INFO] Initializing RecordLevelEmbedder...
# [INFO] Detecting categorical blocks...
# [INFO] Detected 3 categorical blocks:
#    - proto: 1 columns
#    - service: 2 columns
#    - state: 3 columns
# [INFO] Embedder initialized with embedding dimension 64.
# [INFO] Building Keras embedding model...
#    - Adding numerical input: dur
#    - Adding numerical input: spkts
#    - Adding numerical input: dpkts
#    - Adding numerical input: sbytes
#    - Adding numerical input: dbytes
#    - Adding numerical input: rate
#    - Adding numerical input: sttl
#    - Adding numerical input: dttl
#    - Adding numerical input: sload
#    - Adding numerical input: dload
#    - Adding numerical input: sloss
#    - Adding numerical input: dloss
#    - Adding numerical input: sinpkt
#    - Adding numerical input: dinpkt
#    - Adding numerical input: sjit
#    - Adding numerical input: djit
#    - Adding numerical input: swin
#    - Adding numerical input: stcpb
#    - Adding numerical input: dtcpb
#    - Adding numerical input: dwin
#    - Adding numerical input: tcprtt
#    - Adding numerical input: synack
#    - Adding numerical input: ackdat
#    - Adding numerical input: smean
#    - Adding numerical input: dmean
#    - Adding numerical input: response_body_len
#    - Adding numerical input: ct_srv_src
#    - Adding numerical input: ct_state_ttl
#    - Adding numerical input: ct_dst_ltm
#    - Adding numerical input: ct_src_dport_ltm
#    - Adding numerical input: ct_dst_sport_ltm
#    - Adding numerical input: ct_dst_src_ltm
#    - Adding numerical input: ct_src_ltm
#    - Adding numerical input: ct_srv_dst
#    - Adding categorical block input: proto (1 columns)
#    - Adding categorical block input: service (2 columns)
#    - Adding categorical block input: state (3 columns)
# [INFO] Concatenating 37 inputs and applying Dense projection to dimension 64.
# I0000 00:00:1752858123.916386      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1752858123.917133      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# [INFO] Projection complete. Output embedding shape: (64,)
# [INFO] Model build complete.
# [INFO] Preparing inputs for embedding. Number of rows: 257673
#    - Prepared numerical input: dur
#    - Prepared numerical input: spkts
#    - Prepared numerical input: dpkts
#    - Prepared numerical input: sbytes
#    - Prepared numerical input: dbytes
#    - Prepared numerical input: rate
#    - Prepared numerical input: sttl
#    - Prepared numerical input: dttl
#    - Prepared numerical input: sload
#    - Prepared numerical input: dload
#    - Prepared numerical input: sloss
#    - Prepared numerical input: dloss
#    - Prepared numerical input: sinpkt
#    - Prepared numerical input: dinpkt
#    - Prepared numerical input: sjit
#    - Prepared numerical input: djit
#    - Prepared numerical input: swin
#    - Prepared numerical input: stcpb
#    - Prepared numerical input: dtcpb
#    - Prepared numerical input: dwin
#    - Prepared numerical input: tcprtt
#    - Prepared numerical input: synack
#    - Prepared numerical input: ackdat
#    - Prepared numerical input: smean
#    - Prepared numerical input: dmean
#    - Prepared numerical input: response_body_len
#    - Prepared numerical input: ct_srv_src
#    - Prepared numerical input: ct_state_ttl
#    - Prepared numerical input: ct_dst_ltm
#    - Prepared numerical input: ct_src_dport_ltm
#    - Prepared numerical input: ct_dst_sport_ltm
#    - Prepared numerical input: ct_dst_src_ltm
#    - Prepared numerical input: ct_src_ltm
#    - Prepared numerical input: ct_srv_dst
#    - Prepared categorical block input: proto
#    - Prepared categorical block input: service
#    - Prepared categorical block input: state
# [INFO] Performing embedding inference...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752858126.313058     119 service.cc:148] XLA service 0x29da17e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1752858126.314390     119 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1752858126.314413     119 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1752858126.377786     119 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   56/8053 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step
# I0000 00:00:1752858126.828791     119 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 8053/8053 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step
# [INFO] Embedding complete. Output shape: (257673, 64)
# [INFO] Embedding DataFrame ready.
#     embed_0   embed_1   embed_2   embed_3   embed_4   embed_5   embed_6  \
# 0  0.105727 -0.491126  0.096118  0.787497  0.139430  0.126505 -0.136054
# 1 -0.245964 -0.408555  0.047193  0.739823  0.195699  0.167427 -0.031143
# 2 -0.223509 -0.528338  0.186076  0.923381  0.206522  0.160716 -0.163520
# 3 -0.154841 -0.536469 -0.007423  0.812202  0.049836  0.175394 -0.138086
# 4 -0.447536 -0.305651 -0.068547  0.966469  0.269786  0.193491 -0.172670
#
#     embed_7   embed_8   embed_9  ...  embed_54  embed_55  embed_56  embed_57  \
# 0  0.219890  0.068683  0.316265  ...  0.785899  0.744949  0.674004  0.052120
# 1  0.074007  0.341343  0.504743  ...  0.710704  0.725935  0.542005 -0.007761
# 2  0.020009  0.131315  0.537496  ...  0.684933  0.712288  0.558745 -0.027768
# 3  0.093044  0.038759  0.492092  ...  0.622540  0.659052  0.520078 -0.218153
# 4  0.126010  0.104026  0.662388  ...  0.857363  0.703695  0.467133  0.261013
#
#    embed_58  embed_59  embed_60  embed_61  embed_62  embed_63
# 0 -0.284844 -0.049330 -0.217098  0.209042  0.010740  0.726952
# 1 -0.714388  0.026663 -0.524630  0.165171 -0.042864  0.914455
# 2 -0.683895  0.020182 -0.552658  0.147648 -0.063949  0.994240
# 3 -0.598310  0.049732 -0.255027  0.312157 -0.160331  0.779831
# 4 -0.818264  0.112270 -0.606073 -0.068618 -0.104183  0.948011
#
# [5 rows x 64 columns]

# %%
# Binary classification
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.models import Model


print(processed_full_df['label'].unique())

binary_target = (processed_full_df['label'] != 0).astype(int).values
unique, counts = np.unique(binary_target, return_counts=True)
print("Classes and their counts:")
for cls, cnt in zip(unique, counts):
    print(f"Class {cls}: {cnt}")
# Out:
# [0 1]
# Classes and their counts:
# Class 0: 93000
# Class 1: 164673

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from transformer import BasicTransformer
from classification import LastTokenClassificationHead
from sklearn.model_selection import train_test_split
import numpy as np  # Just in case

# Input data
X_embed = embedded_df.values                   # shape: (num_samples, embed_dim)
X_embed_seq = tf.expand_dims(X_embed, axis=1)  # shape: (batch_size, 1, embed_dim)

input_layer = Input(shape=(1, X_embed.shape[1]), name="record_input")

# Transformer block
transformer = BasicTransformer(
    n_layers=2,
    internal_size=128,
    n_heads=4,
    verbose=True  # See progress!
)

x = transformer.apply(input_layer, training=True)

# Classification head
classification_head = LastTokenClassificationHead()
x = classification_head.apply(x)

# MLP head
for i, layer_size in enumerate([128]):
    x = Dense(layer_size, activation="relu", name=f"classification_mlp_{i}_{layer_size}")(x)
    x = Dropout(0.1)(x)

# Output layer for binary classification
output_layer = Dense(1, activation="sigmoid", name="binary_output")(x)

# Build the model
model = Model(inputs=input_layer, outputs=output_layer)
model.summary()

# Compile the model
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"],
    jit_compile=True
)

# Prepare data
X_np = X_embed_seq.numpy() if hasattr(X_embed_seq, 'numpy') else np.array(X_embed_seq)

X_train, X_val, y_train, y_val = train_test_split(
    X_np, binary_target, test_size=0.2, random_state=42, stratify=binary_target
)

# Define early stopping callback
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

# Train the model
model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=32,
    callbacks=[early_stop]
)
# Out:
# [BasicTransformer] Applying Encoder Block 1/2
# [EncoderBlock] Input shape: (None, 1, 64)
# [EncoderBlock] Output shape: (None, 1, 64)
# [EncoderBlock] Input shape: (None, 1, 64)
# [EncoderBlock] Output shape: (None, 1, 64)
# [BasicTransformer] Applying Encoder Block 2/2
# [EncoderBlock] Input shape: (None, 1, 64)
# [EncoderBlock] Output shape: (None, 1, 64)
# [EncoderBlock] Input shape: (None, 1, 64)
# [EncoderBlock] Output shape: (None, 1, 64)
# [BasicTransformer] Final output shape: (None, 1, 64)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ record_input (InputLayer)       │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block_0_transformer_encoder     │ (None, 1, 64)          │       149,504 │
# │ (TransformerEncoderBlock)       │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block_1_transformer_encoder     │ (None, 1, 64)          │       149,504 │
# │ (TransformerEncoderBlock)       │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ slice_last (Lambda)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ classification_mlp_0_128        │ (None, 128)            │         8,320 │
# │ (Dense)                         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ binary_output (Dense)           │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 307,457 (1.17 MB)
#  Trainable params: 307,457 (1.17 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# [EncoderBlock] Input shape: (None, 1, 64)
# [EncoderBlock] Output shape: (None, 1, 64)
# [EncoderBlock] Input shape: (None, 1, 64)
# [EncoderBlock] Output shape: (None, 1, 64)
# [EncoderBlock] Input shape: (None, 1, 64)
# [EncoderBlock] Output shape: (None, 1, 64)
# [EncoderBlock] Input shape: (None, 1, 64)
# [EncoderBlock] Output shape: (None, 1, 64)
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8990 - loss: 0.2176[EncoderBlock] Input shape: (None, 1, 64)
# [EncoderBlock] Output shape: (None, 1, 64)
# [EncoderBlock] Input shape: (None, 1, 64)
# [EncoderBlock] Output shape: (None, 1, 64)
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 44s 5ms/step - accuracy: 0.8990 - loss: 0.2176 - val_accuracy: 0.9193 - val_loss: 0.1776
# Epoch 2/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.9151 - loss: 0.1797 - val_accuracy: 0.9200 - val_loss: 0.1662
# Epoch 3/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.9189 - loss: 0.1692 - val_accuracy: 0.9217 - val_loss: 0.1713
# Epoch 4/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.9212 - loss: 0.1629 - val_accuracy: 0.9271 - val_loss: 0.1563
# Epoch 5/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step - accuracy: 0.9229 - loss: 0.1578 - val_accuracy: 0.9301 - val_loss: 0.1466
# Epoch 6/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - accuracy: 0.9247 - loss: 0.1529 - val_accuracy: 0.9275 - val_loss: 0.1443
# Epoch 7/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.9268 - loss: 0.1498 - val_accuracy: 0.9329 - val_loss: 0.1414
# Epoch 8/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.9275 - loss: 0.1482 - val_accuracy: 0.9299 - val_loss: 0.1421
# Epoch 9/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.9263 - loss: 0.1498 - val_accuracy: 0.9307 - val_loss: 0.1412
# Epoch 10/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.9282 - loss: 0.1468 - val_accuracy: 0.9330 - val_loss: 0.1366
# Epoch 11/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.9295 - loss: 0.1437 - val_accuracy: 0.9337 - val_loss: 0.1340
# Epoch 12/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step - accuracy: 0.9293 - loss: 0.1432 - val_accuracy: 0.9318 - val_loss: 0.1396
# Epoch 13/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.9298 - loss: 0.1434 - val_accuracy: 0.9328 - val_loss: 0.1366
# Epoch 14/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.9304 - loss: 0.1407 - val_accuracy: 0.9295 - val_loss: 0.1476
# Epoch 15/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.9301 - loss: 0.1411 - val_accuracy: 0.9334 - val_loss: 0.1352
# Epoch 16/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.9312 - loss: 0.1410 - val_accuracy: 0.9339 - val_loss: 0.1330
# Epoch 17/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.9310 - loss: 0.1412 - val_accuracy: 0.9306 - val_loss: 0.1357
# Epoch 18/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.9310 - loss: 0.1398 - val_accuracy: 0.9341 - val_loss: 0.1337
# Epoch 19/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.9316 - loss: 0.1389 - val_accuracy: 0.9340 - val_loss: 0.1352
# Epoch 20/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.9327 - loss: 0.1368 - val_accuracy: 0.9349 - val_loss: 0.1336
# Epoch 21/50
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.9314 - loss: 0.1369 - val_accuracy: 0.9353 - val_loss: 0.1336
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 16.

# %%
# evaluate the model
results = model.evaluate(X_val, y_val)
print(f"Validation loss: {results[0]:.4f}, Validation accuracy: {results[1]:.4f}")
# Out:
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9320 - loss: 0.1332
# Validation loss: 0.1330, Validation accuracy: 0.9339

# %%
from sklearn.metrics import f1_score, confusion_matrix
import numpy as np

# Predict probabilities
y_pred_prob = model.predict(X_val)
y_pred = (y_pred_prob >= 0.5).astype(int).flatten()

# F1
f1 = f1_score(y_val, y_pred)
print(f"F1 Score: {f1:.4f}")

# Confusion matrix
cm = confusion_matrix(y_val, y_pred, labels=[0, 1])
print("Confusion Matrix:\n", cm)

if cm.shape == (2, 2):
    tn, fp, fn, tp = cm.ravel()
    detection_rate = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    false_alarm_rate = fp / (fp + tn) if (fp + tn) > 0 else 0.0
    print(f"Detection Rate (Recall): {detection_rate:.4f}")
    print(f"False Alarm Rate: {false_alarm_rate:.4f}")
else:
    print("Confusion matrix does not contain both classes!")
    print("Check your labels: y_val:", np.unique(y_val), " y_pred:", np.unique(y_pred))
# Out:
# [EncoderBlock] Input shape: (32, 1, 64)
# [EncoderBlock] Output shape: (32, 1, 64)
# [EncoderBlock] Input shape: (32, 1, 64)
# [EncoderBlock] Output shape: (32, 1, 64)
# 1581/1611 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step[EncoderBlock] Input shape: (None, 1, 64)
# [EncoderBlock] Output shape: (None, 1, 64)
# [EncoderBlock] Input shape: (None, 1, 64)
# [EncoderBlock] Output shape: (None, 1, 64)
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# F1 Score: 0.9486
# Confusion Matrix:
#  [[16735  1865]
#  [ 1540 31395]]
# Detection Rate (Recall): 0.9532
# False Alarm Rate: 0.1003
